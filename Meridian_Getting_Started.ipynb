# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/google/meridian/blob/main/demo/Meridian_Getting_Started.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/google/meridian/blob/main/demo/Meridian_Getting_Started.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# # **Introduction to Meridian Demo**

# %% [markdown]
# Welcome to the Meridian end-to-end demo. This simplified demo showcases the fundamental functionalities and basic usage of the library, including working examples of the major modeling steps:
#
#
# <ol start="0">
#   <li><a href="#install">Install</a></li>
#   <li><a href="#load-data">Load the data</a></li>
#   <li><a href="#configure-model">Configure the model</a></li>
#   <li><a href="#model-diagnostics">Run model diagnostics</a></li>
#   <li><a href="#generate-summary">Generate model results & two-page output</a></li>
#   <li><a href="#generate-optimize">Run budget optimization & two-page output</a></li>
#   <li><a href="#save-model">Save the model object</a></li>
# </ol>
#
#
# Note that this notebook skips all of the exploratory data analysis and preprocessing steps. It assumes that you have completed these tasks before reaching this point in the demo.
#
# This notebook utilizes sample data. As a result, the numbers and results obtained might not accurately reflect what you encounter when working with a real dataset.

# %% [markdown]
# <a name="install"></a>
# ## Step 0: Install

# %% [markdown]
# 1\. Make sure you are using one of the available GPU Colab runtimes which is **required** to run Meridian. You can change your notebook's runtime in `Runtime > Change runtime type` in the menu. All users can use the T4 GPU runtime which is sufficient to run the demo colab, free of charge. Users who have purchased one of Colab's paid plans have access to premium GPUs (such as V100, A100 or L4 Nvidia GPU).

# %% [markdown]
# 2\. Install the latest version of Meridian, and verify that GPU is available.

# %%
# Install meridian: from PyPI @ latest release
# !pip install --upgrade google-meridian[colab,and-cuda]

# Install meridian: from PyPI @ specific version
# !pip install google-meridian[colab,and-cuda]==1.0.3

# Install meridian: from GitHub @HEAD
# !pip install --upgrade "google-meridian[colab,and-cuda] @ git+https://github.com/google/meridian.git"

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_probability as tfp
import arviz as az

import IPython

from meridian import constants
from meridian.data import load
from meridian.data import test_utils
from meridian.model import model
from meridian.model import spec
from meridian.model import prior_distribution
from meridian.analysis import optimizer
from meridian.analysis import analyzer
from meridian.analysis import visualizer
from meridian.analysis import summarizer
from meridian.analysis import formatter

# check if GPU is available
# from psutil import virtual_memory
# ram_gb = virtual_memory().total / 1e9
# print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# print("Num CPUs Available: ", len(tf.config.experimental.list_physical_devices('CPU')))

# %% [markdown]
# <a name="load-data"></a>
# ## Step 1: Load the data

# %% [markdown]
# Load the [simulated dataset in CSV format](https://github.com/google/meridian/blob/main/meridian/data/simulated_data/csv/geo_all_channels.csv) as follows.

# %% [markdown]
# 1\. Map the column names to their corresponding variable types. For example, the column names 'GQV' and 'Competitor_Sales' are mapped to `controls`. The required variable types are `time`, `controls`, `population`, `kpi`, `revenue_per_kpi`, `media` and `spend`. If your data includes organic media or non-media treatments, you can add them using `organic_media` and `non_media_treatments` arguments. For the definition of each variable, see
# [Collect and organize your data](https://developers.google.com/meridian/docs/user-guide/collect-data).

# %%
coord_to_columns = load.CoordToColumns(
    time='time',
    geo='geo',
    controls=['sentiment_score_control', 'competitor_sales_control'],
    population='population',
    kpi='conversions',
    revenue_per_kpi='revenue_per_conversion',
    media=[
        'Channel0_impression',
        'Channel1_impression',
        'Channel2_impression',
        'Channel3_impression',
        'Channel4_impression',
    ],
    media_spend=[
        'Channel0_spend',
        'Channel1_spend',
        'Channel2_spend',
        'Channel3_spend',
        'Channel4_spend',
    ],
    organic_media=['Organic_channel0_impression'],
    non_media_treatments=['Promo'],
)

# %% [markdown]
# 2\. Map the media variables and the media spends to the designated channel names intended for display in the two-page HTML output. In the following example,  'Channel0_impression' and 'Channel0_spend' are connected to the same channel, 'Channel0'.

# %%
correct_media_to_channel = {
    'Channel0_impression': 'Channel_0',
    'Channel1_impression': 'Channel_1',
    'Channel2_impression': 'Channel_2',
    'Channel3_impression': 'Channel_3',
    'Channel4_impression': 'Channel_4',
}
correct_media_spend_to_channel = {
    'Channel0_spend': 'Channel_0',
    'Channel1_spend': 'Channel_1',
    'Channel2_spend': 'Channel_2',
    'Channel3_spend': 'Channel_3',
    'Channel4_spend': 'Channel_4',
}

# %% [markdown]
# 3\. Load the CSV data using `CsvDataLoader`. Note that `csv_path` is the path to the data file location.

# %%
loader = load.CsvDataLoader(
    csv_path="https://raw.githubusercontent.com/google/meridian/refs/heads/main/meridian/data/simulated_data/csv/geo_all_channels.csv",
    kpi_type='non_revenue',
    coord_to_columns=coord_to_columns,
    media_to_channel=correct_media_to_channel,
    media_spend_to_channel=correct_media_spend_to_channel,
)
data = loader.load()
# Out:
# /Users/clairedanaher/.pyenv/versions/meridian/lib/python3.11/site-packages/meridian/data/load.py:1033: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.df[geo_column_name] = self.df[geo_column_name].replace(

# %% [markdown]
# Note that the simulated data here does not contain reach and frequency. We recommend including reach and frequency data whenever they are available. For information about the advantages of utilizing reach and frequency, see [Bayesian Hierarchical Media Mix Model Incorporating Reach and Frequency Data](https://research.google/pubs/bayesian-hierarchical-media-mix-model-incorporating-reach-and-frequency-data/#:~:text=By%20incorporating%20R%26F%20into%20MMM,based%20on%20optimal%20frequency%20recommendations.). For code snippet for loading reach and frequency data, see [Load geo-level data with reach and frequency](https://developers.google.com/meridian/docs/user-guide/load-geo-data-with-rf)
#
# The documentation provides guidance for instances where reach and frequency data is accessible for specific channels. Additionally, for information about how to load other data types and formats, including data with reach and frequency, see [Supported data types and formats](https://developers.google.com/meridian/docs/user-guide/supported-data-types-formats).

# %% [markdown]
# <a name="configure-model"></a>
# ## Step 2: Configure the model

# %% [markdown]
# Meridian uses Bayesian framework and Markov Chain Monte Carlo (MCMC) algorithms to sample from the posterior distribution.
#
# 1\. Inititalize the `Meridian` class by passing the loaded data and the customized model specification. One advantage of Meridian lies in its capacity to calibrate the model directly through ROI priors, as described in [Media Mix Model Calibration With Bayesian Priors](https://research.google/pubs/media-mix-model-calibration-with-bayesian-priors/). In this particular example, the ROI priors for all media channels are identical, with each being represented as Lognormal(0.2, 0.9).

# %%
roi_mu = 0.2     # Mu for ROI prior for each media channel.
roi_sigma = 0.9  # Sigma for ROI prior for each media channel.
prior = prior_distribution.PriorDistribution(
    roi_m=tfp.distributions.LogNormal(roi_mu, roi_sigma, name=constants.ROI_M)
)
model_spec = spec.ModelSpec(prior=prior)

mmm = model.Meridian(input_data=data, model_spec=model_spec)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748899155.355982 1337455 service.cc:148] XLA service 0x31ac5fe20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748899155.356063 1337455 service.cc:156]   StreamExecutor device (0): Host, Default Version
# I0000 00:00:1748899155.373070 1337455 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %% [markdown]
# 2\. Use the `sample_prior()` and `sample_posterior()` methods to obtain samples from the prior and posterior distributions of model parameters. If you are using the T4 GPU runtime this step may take about 10 minutes for the provided data set.

# %%
# %%time
mmm.sample_prior(500)
mmm.sample_posterior(n_chains=10, n_adapt=2000, n_burnin=500, n_keep=1000, seed=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'mmm.sample_prior(500)\nmmm.sample_posterior(n_chains=10, n_adapt=2000, n_burnin=500, n_keep=1000, seed=1)\n')
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2549, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2547 with self.builtin_trap:
#    2548     args = (magic_arg_s, cell)
# -> 2549     result = fn(*args, **kwargs)
#    2551 # The code below prevents the output from being displayed
#    2552 # when using magics with decorator @output_can_be_silenced
#    2553 # when the last Python token in the expression is a ';'.
#    2554 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/IPython/core/magics/execution.py:1395, in ExecutionMagics.time(self, line, cell, local_ns)
#    1393     if expr_val is not None:
#    1394         code_2 = self.shell.compile(expr_val, source, 'eval')
# -> 1395         out = eval(code_2, glob, local_ns)
#    1396 except Exception:
#    1397     self.shell.showtraceback()
#
# File <timed exec>:2
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/meridian/model/model.py:1522, in Meridian.sample_posterior(self, n_chains, n_adapt, n_burnin, n_keep, current_state, init_step_size, dual_averaging_kwargs, max_tree_depth, max_energy_diff, unrolled_leapfrog_steps, parallel_iterations, seed, **pins)
#    1445 def sample_posterior(
#    1446     self,
#    1447     n_chains: Sequence[int] | int,
#    (...)   1459     **pins,
#    1460 ):
#    1461   """Runs Markov Chain Monte Carlo (MCMC) sampling of posterior distributions.
#    1462
#    1463   For more information about the arguments, see [`windowed_adaptive_nuts`]
#    (...)   1520       (https://developers.google.com/meridian/docs/advanced-modeling/model-debugging#gpu-oom-error).
#    1521   """
# -> 1522   posterior_inference_data = self.posterior_sampler_callable(
#    1523       n_chains,
#    1524       n_adapt,
#    1525       n_burnin,
#    1526       n_keep,
#    1527       current_state,
#    1528       init_step_size,
#    1529       dual_averaging_kwargs,
#    1530       max_tree_depth,
#    1531       max_energy_diff,
#    1532       unrolled_leapfrog_steps,
#    1533       parallel_iterations,
#    1534       seed,
#    1535       **pins,
#    1536   )
#    1537   self.inference_data.extend(posterior_inference_data, join="right")
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/meridian/model/posterior_sampler.py:557, in PosteriorMCMCSampler.__call__(self, n_chains, n_adapt, n_burnin, n_keep, current_state, init_step_size, dual_averaging_kwargs, max_tree_depth, max_energy_diff, unrolled_leapfrog_steps, parallel_iterations, seed, **pins)
#     555 for n_chains_batch in n_chains_list:
#     556   try:
# --> 557     mcmc = _xla_windowed_adaptive_nuts(
#     558         n_draws=n_burnin + n_keep,
#     559         joint_dist=self._get_joint_dist(),
#     560         n_chains=n_chains_batch,
#     561         num_adaptation_steps=n_adapt,
#     562         current_state=current_state,
#     563         init_step_size=init_step_size,
#     564         dual_averaging_kwargs=dual_averaging_kwargs,
#     565         max_tree_depth=max_tree_depth,
#     566         max_energy_diff=max_energy_diff,
#     567         unrolled_leapfrog_steps=unrolled_leapfrog_steps,
#     568         parallel_iterations=parallel_iterations,
#     569         seed=seed,
#     570         **pins,
#     571     )
#     572   except tf.errors.ResourceExhaustedError as error:
#     573     raise MCMCOOMError(
#     574         "ERROR: Out of memory. Try reducing `n_keep` or pass a list of"
#     575         " integers as `n_chains` to sample chains serially (see"
#     576         " https://developers.google.com/meridian/docs/advanced-modeling/model-debugging#gpu-oom-error)"
#     577     ) from error
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/meridian/model/posterior_sampler.py:79, in _xla_windowed_adaptive_nuts(**kwargs)
#      76 @tf.function(autograph=False, jit_compile=True)
#      77 def _xla_windowed_adaptive_nuts(**kwargs):
#      78   """XLA wrapper for windowed_adaptive_nuts."""
# ---> 79   return tfp.experimental.mcmc.windowed_adaptive_nuts(**kwargs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/experimental/mcmc/windowed_sampling.py:715, in windowed_adaptive_nuts(n_draws, joint_dist, n_chains, num_adaptation_steps, current_state, init_step_size, dual_averaging_kwargs, max_tree_depth, max_energy_diff, unrolled_leapfrog_steps, parallel_iterations, trace_fn, return_final_kernel_results, discard_tuning, chain_axis_names, seed, **pins)
#     708 dual_averaging_kwargs.setdefault('target_accept_prob', 0.85)
#     709 proposal_kernel_kwargs = {
#     710     'step_size': init_step_size,
#     711     'max_tree_depth': max_tree_depth,
#     712     'max_energy_diff': max_energy_diff,
#     713     'unrolled_leapfrog_steps': unrolled_leapfrog_steps,
#     714     'parallel_iterations': parallel_iterations}
# --> 715 return _windowed_adaptive_impl(
#     716     n_draws=n_draws,
#     717     joint_dist=joint_dist,
#     718     kind='nuts',
#     719     n_chains=n_chains,
#     720     proposal_kernel_kwargs=proposal_kernel_kwargs,
#     721     current_state=current_state,
#     722     num_adaptation_steps=num_adaptation_steps,
#     723     dual_averaging_kwargs=dual_averaging_kwargs,
#     724     trace_fn=trace_fn,
#     725     return_final_kernel_results=return_final_kernel_results,
#     726     discard_tuning=discard_tuning,
#     727     chain_axis_names=chain_axis_names,
#     728     seed=seed,
#     729     **pins)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/experimental/mcmc/windowed_sampling.py:934, in _windowed_adaptive_impl(n_draws, joint_dist, kind, n_chains, proposal_kernel_kwargs, num_adaptation_steps, current_state, dual_averaging_kwargs, trace_fn, return_final_kernel_results, discard_tuning, seed, chain_axis_names, **pins)
#     926 initial_running_variance = [
#     927     sample_stats.RunningVariance.from_stats(  # pylint: disable=g-complex-comprehension
#     928         num_samples=tf.zeros([], part.dtype),
#     929         mean=tf.zeros_like(part),
#     930         variance=tf.ones_like(part)) for part in initial_transformed_position
#     931 ]
#     932 # TODO(phandu): Consider splitting out warmup and post warmup phases
#     933 # to avoid executing adaptation code during the post warmup phase.
# --> 934 ret = _do_sampling(
#     935     kind=kind,
#     936     proposal_kernel_kwargs=proposal_kernel_kwargs,
#     937     dual_averaging_kwargs=dual_averaging_kwargs,
#     938     num_draws=n_draws if discard_tuning else n_draws + num_adaptation_steps,
#     939     num_burnin_steps=num_adaptation_steps if discard_tuning else 0,
#     940     initial_position=initial_transformed_position,
#     941     initial_running_variance=initial_running_variance,
#     942     bijector=bijector,
#     943     trace_fn=trace_fn,
#     944     return_final_kernel_results=return_final_kernel_results,
#     945     chain_axis_names=chain_axis_names,
#     946     shard_axis_names=shard_axis_names,
#     947     seed=sample_seed)
#     949 if return_final_kernel_results:
#     950   draws, trace, fkr = ret
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/experimental/mcmc/windowed_sampling.py:551, in _do_sampling(kind, proposal_kernel_kwargs, dual_averaging_kwargs, num_draws, num_burnin_steps, initial_position, initial_running_variance, trace_fn, bijector, return_final_kernel_results, seed, chain_axis_names, shard_axis_names)
#     543 """Sample from base HMC kernel."""
#     544 kernel = make_windowed_adapt_kernel(
#     545     kind=kind,
#     546     proposal_kernel_kwargs=proposal_kernel_kwargs,
#    (...)    549     chain_axis_names=chain_axis_names,
#     550     shard_axis_names=shard_axis_names)
# --> 551 return sample.sample_chain(
#     552     num_draws,
#     553     initial_position,
#     554     kernel=kernel,
#     555     num_burnin_steps=num_burnin_steps,
#     556     # pylint: disable=g-long-lambda
#     557     trace_fn=lambda state, pkr: trace_fn(
#     558         state, bijector, pkr.step <= dual_averaging_kwargs[
#     559             'num_adaptation_steps'], pkr.inner_results.inner_results.
#     560         inner_results),
#     561     # pylint: enable=g-long-lambda
#     562     return_final_kernel_results=return_final_kernel_results,
#     563     seed=seed)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/mcmc/sample.py:359, in sample_chain(num_results, current_state, previous_kernel_results, kernel, num_burnin_steps, num_steps_between_results, trace_fn, return_final_kernel_results, parallel_iterations, seed, name)
#     352   seed, next_state, current_kernel_results = loop_util.smart_for_loop(
#     353       loop_num_iter=num_steps,
#     354       body_fn=_seeded_one_step,
#     355       initial_loop_vars=list(seed_state_and_results),
#     356       parallel_iterations=parallel_iterations)
#     357   return seed, next_state, current_kernel_results
# --> 359 (_, _, final_kernel_results), (all_states, trace) = loop_util.trace_scan(
#     360     loop_fn=_trace_scan_fn,
#     361     initial_state=(seed, current_state, previous_kernel_results),
#     362     elems=tf.one_hot(
#     363         indices=0,
#     364         depth=num_results,
#     365         on_value=1 + num_burnin_steps,
#     366         off_value=1 + num_steps_between_results,
#     367         dtype=tf.int32),
#     368     # pylint: disable=g-long-lambda
#     369     trace_fn=lambda seed_state_and_results: (
#     370         seed_state_and_results[1], trace_fn(*seed_state_and_results[1:])),
#     371     # pylint: enable=g-long-lambda
#     372     parallel_iterations=parallel_iterations)
#     374 if return_final_kernel_results:
#     375   return CheckpointableStatesAndTrace(
#     376       all_states=all_states,
#     377       trace=trace,
#     378       final_kernel_results=final_kernel_results)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/loop_util.py:232, in trace_scan(loop_fn, initial_state, elems, trace_fn, trace_criterion_fn, static_trace_allocation_size, condition_fn, parallel_iterations, name)
#     224   trace_arrays, num_steps_traced = ps.cond(
#     225       trace_criterion_fn(state) if trace_criterion_fn else True,
#     226       lambda: (trace_one_step(num_steps_traced, trace_arrays, state),  # pylint: disable=g-long-lambda
#     227                num_steps_traced + 1),
#     228       lambda: (trace_arrays, num_steps_traced))
#     230   return i + 1, state, num_steps_traced, trace_arrays
# --> 232 _, final_state, _, trace_arrays = tf.while_loop(
#     233     cond=condition_fn if condition_fn is not None else lambda *_: True,
#     234     body=_body,
#     235     loop_vars=(0, initial_state, 0, trace_arrays),
#     236     maximum_iterations=length,
#     237     parallel_iterations=parallel_iterations)
#     239 # unflatten
#     240 stacked_trace = tf.nest.pack_sequence_as(
#     241     initial_trace, [ta.stack() for ta in trace_arrays],
#     242     expand_composites=True)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/deprecation.py:660, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     652           _PRINTED_WARNING[(func, arg_name)] = True
#     653         _log_deprecation(
#     654             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     655             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)    658             'in a future version' if date is None else
#     659             ('after %s' % date), instructions)
# --> 660 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py:241, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      35 @tf_export("while_loop", v1=[])
#      36 @deprecation.deprecated_arg_values(
#      37     None,
#    (...)     52                   maximum_iterations=None,
#      53                   name=None):
#      54   """Repeat `body` while the condition `cond` is true.
#      55
#      56   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)    239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#     245       shape_invariants=shape_invariants,
#     246       parallel_iterations=parallel_iterations,
#     247       back_prop=back_prop,
#     248       swap_memory=swap_memory,
#     249       name=name,
#     250       maximum_iterations=maximum_iterations,
#     251       return_same_structure=True)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py:440, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     437 executing_eagerly = context.executing_eagerly()
#     438 if (util.EnableControlFlowV2(ops.get_default_graph()) and
#     439     not executing_eagerly):
# --> 440   return while_v2.while_loop(
#     441       cond,
#     442       body,
#     443       loop_vars,
#     444       shape_invariants=shape_invariants,
#     445       parallel_iterations=parallel_iterations,
#     446       maximum_iterations=maximum_iterations,
#     447       name=name,
#     448       return_same_structure=return_same_structure,
#     449       back_prop=back_prop)
#     451 with ops.name_scope(name, "while", loop_vars):
#     452   if not loop_vars:
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/ops/while_v2.py:202, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, maximum_iterations, name, return_same_structure, back_prop)
#     198   # TODO(srbs): Update lowering code to create _Enter nodes with
#     199   # is_constant=True for inputs that are directly passed to outputs.
#     200   return [loop_counter + 1, maximum_iterations_arg] + list(outputs)
# --> 202 body_graph = func_graph_module.func_graph_from_py_func(
#     203     body_name,
#     204     wrapped_body,
#     205     [],  # We provide signature instead of args.
#     206     {},
#     207     signature=func_graph_signature,
#     208     func_graph=util.WhileBodyFuncGraph(
#     209         body_name, collections=ops.get_default_graph()._collections),  # pylint: disable=protected-access
#     210     add_control_dependencies=add_control_dependencies)
#     211 # Add external captures of body to the list of loop vars.
#     212 # Note that external tensors will be treated as loop invariants, i.e.,
#     213 # the value of that tensor in each iteration is the same as it was at the
#     214 # beginning of the loop execution.
#     215 deferred_external_captures = nest.flatten(
#     216     [c() for c in body_graph.deferred_external_captures],
#     217     expand_composites=True)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/ops/while_v2.py:180, in while_loop.<locals>.wrapped_body(loop_counter, maximum_iterations_arg, *args)
#     173   ops.get_default_graph().capture(t)
#     175 # Convert the flow variables in `args` to TensorArrays. `args` should
#     176 # already have the same structure as `orig_loop_vars` but currently there
#     177 # is no nest.zip so we call `_pack_sequence_as` which flattens `args`,
#     178 # converts flows in `args` to TensorArrays and packs it into the
#     179 # structure of `loop_vars_signature`.
# --> 180 outputs = body(
#     181     *_pack_sequence_as(loop_vars_signature, flat_orig_loop_vars, args))
#     182 if not nest.is_nested(outputs):
#     183   outputs = [outputs]
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/loop_util.py:222, in trace_scan.<locals>._body(i, state, num_steps_traced, trace_arrays)
#     220 def _body(i, state, num_steps_traced, trace_arrays):
#     221   elem = elems_array.read(i)
# --> 222   state = loop_fn(state, elem)
#     224   trace_arrays, num_steps_traced = ps.cond(
#     225       trace_criterion_fn(state) if trace_criterion_fn else True,
#     226       lambda: (trace_one_step(num_steps_traced, trace_arrays, state),  # pylint: disable=g-long-lambda
#     227                num_steps_traced + 1),
#     228       lambda: (trace_arrays, num_steps_traced))
#     230   return i + 1, state, num_steps_traced, trace_arrays
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/mcmc/sample.py:352, in sample_chain.<locals>._trace_scan_fn(seed_state_and_results, num_steps)
#     351 def _trace_scan_fn(seed_state_and_results, num_steps):
# --> 352   seed, next_state, current_kernel_results = loop_util.smart_for_loop(
#     353       loop_num_iter=num_steps,
#     354       body_fn=_seeded_one_step,
#     355       initial_loop_vars=list(seed_state_and_results),
#     356       parallel_iterations=parallel_iterations)
#     357   return seed, next_state, current_kernel_results
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/loop_util.py:111, in smart_for_loop(loop_num_iter, body_fn, initial_loop_vars, parallel_iterations, unroll_threshold, name)
#     101 if (loop_num_iter_ is None
#     102     or tf.executing_eagerly()
#     103     # large values for loop_num_iter_ will cause ridiculously slow
#    (...)    108   # Cast to int32 to run the comparison against i in host memory,
#     109   # where while/LoopCond needs it.
#     110   loop_num_iter = tf.cast(loop_num_iter, dtype=tf.int32)
# --> 111   return tf.while_loop(
#     112       cond=lambda i, *args: i < loop_num_iter,
#     113       body=lambda i, *args: [i + 1] + list(body_fn(*args)),
#     114       loop_vars=[np.int32(0)] + initial_loop_vars,
#     115       parallel_iterations=parallel_iterations
#     116   )[1:]
#     117 result = initial_loop_vars
#     118 for _ in range(loop_num_iter_):
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/deprecation.py:660, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     652           _PRINTED_WARNING[(func, arg_name)] = True
#     653         _log_deprecation(
#     654             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     655             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)    658             'in a future version' if date is None else
#     659             ('after %s' % date), instructions)
# --> 660 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py:241, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      35 @tf_export("while_loop", v1=[])
#      36 @deprecation.deprecated_arg_values(
#      37     None,
#    (...)     52                   maximum_iterations=None,
#      53                   name=None):
#      54   """Repeat `body` while the condition `cond` is true.
#      55
#      56   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)    239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#     245       shape_invariants=shape_invariants,
#     246       parallel_iterations=parallel_iterations,
#     247       back_prop=back_prop,
#     248       swap_memory=swap_memory,
#     249       name=name,
#     250       maximum_iterations=maximum_iterations,
#     251       return_same_structure=True)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/ops/while_loop.py:440, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     437 executing_eagerly = context.executing_eagerly()
#     438 if (util.EnableControlFlowV2(ops.get_default_graph()) and
#     439     not executing_eagerly):
# --> 440   return while_v2.while_loop(
#     441       cond,
#     442       body,
#     443       loop_vars,
#     444       shape_invariants=shape_invariants,
#     445       parallel_iterations=parallel_iterations,
#     446       maximum_iterations=maximum_iterations,
#     447       name=name,
#     448       return_same_structure=return_same_structure,
#     449       back_prop=back_prop)
#     451 with ops.name_scope(name, "while", loop_vars):
#     452   if not loop_vars:
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/ops/while_v2.py:202, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, maximum_iterations, name, return_same_structure, back_prop)
#     198   # TODO(srbs): Update lowering code to create _Enter nodes with
#     199   # is_constant=True for inputs that are directly passed to outputs.
#     200   return [loop_counter + 1, maximum_iterations_arg] + list(outputs)
# --> 202 body_graph = func_graph_module.func_graph_from_py_func(
#     203     body_name,
#     204     wrapped_body,
#     205     [],  # We provide signature instead of args.
#     206     {},
#     207     signature=func_graph_signature,
#     208     func_graph=util.WhileBodyFuncGraph(
#     209         body_name, collections=ops.get_default_graph()._collections),  # pylint: disable=protected-access
#     210     add_control_dependencies=add_control_dependencies)
#     211 # Add external captures of body to the list of loop vars.
#     212 # Note that external tensors will be treated as loop invariants, i.e.,
#     213 # the value of that tensor in each iteration is the same as it was at the
#     214 # beginning of the loop execution.
#     215 deferred_external_captures = nest.flatten(
#     216     [c() for c in body_graph.deferred_external_captures],
#     217     expand_composites=True)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/ops/while_v2.py:180, in while_loop.<locals>.wrapped_body(loop_counter, maximum_iterations_arg, *args)
#     173   ops.get_default_graph().capture(t)
#     175 # Convert the flow variables in `args` to TensorArrays. `args` should
#     176 # already have the same structure as `orig_loop_vars` but currently there
#     177 # is no nest.zip so we call `_pack_sequence_as` which flattens `args`,
#     178 # converts flows in `args` to TensorArrays and packs it into the
#     179 # structure of `loop_vars_signature`.
# --> 180 outputs = body(
#     181     *_pack_sequence_as(loop_vars_signature, flat_orig_loop_vars, args))
#     182 if not nest.is_nested(outputs):
#     183   outputs = [outputs]
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/loop_util.py:113, in smart_for_loop.<locals>.<lambda>(i, *args)
#     101 if (loop_num_iter_ is None
#     102     or tf.executing_eagerly()
#     103     # large values for loop_num_iter_ will cause ridiculously slow
#    (...)    108   # Cast to int32 to run the comparison against i in host memory,
#     109   # where while/LoopCond needs it.
#     110   loop_num_iter = tf.cast(loop_num_iter, dtype=tf.int32)
#     111   return tf.while_loop(
#     112       cond=lambda i, *args: i < loop_num_iter,
# --> 113       body=lambda i, *args: [i + 1] + list(body_fn(*args)),
#     114       loop_vars=[np.int32(0)] + initial_loop_vars,
#     115       parallel_iterations=parallel_iterations
#     116   )[1:]
#     117 result = initial_loop_vars
#     118 for _ in range(loop_num_iter_):
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/mcmc/sample.py:349, in sample_chain.<locals>._seeded_one_step(seed, *state_and_results)
#     345 step_seed, passalong_seed = (
#     346     samplers.split_seed(seed) if is_seeded else (None, seed))
#     347 one_step_kwargs = dict(seed=step_seed) if is_seeded else {}
#     348 return [passalong_seed] + list(
# --> 349     kernel.one_step(*state_and_results, **one_step_kwargs))
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/experimental/mcmc/windowed_sampling.py:496, in WindowedAdaptation.one_step(self, current_state, previous_kernel_results, seed)
#     484 option = (
#     485     tf.cast(is_first_fast_window_start, dtype=tf.int32) +
#     486     tf.cast(is_first_slow_window_start, dtype=tf.int32) * 2 +
#     487     tf.cast(is_slow_window_start, dtype=tf.int32) * 3 +
#     488     tf.cast(is_last_window_start, dtype=tf.int32) * 4)
#     489 previous_inner_results = mcmc_util.choose_from(option, [
#     490     previous_inner_results,
#     491     first_fast_window_update(),
#    (...)    494     last_window_update()
#     495 ])
# --> 496 new_state, new_inner_results = self.inner_kernel.one_step(
#     497     current_state, previous_inner_results, seed=seed)
#     498 return new_state, previous_kernel_results._replace(
#     499     inner_results=new_inner_results, step=previous_step + 1)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/experimental/mcmc/diagonal_mass_matrix_adaptation.py:199, in DiagonalMassMatrixAdaptation.one_step(self, current_state, previous_kernel_results, seed)
#     197 # Step the inner kernel.
#     198 inner_kwargs = {} if seed is None else dict(seed=seed)
# --> 199 new_state, new_inner_results = self.inner_kernel.one_step(
#     200     current_state, inner_results, **inner_kwargs)
#     202 def update_running_variance():
#     203   diags = [variance_part.variance() for variance_part in variance_parts]
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/mcmc/dual_averaging_step_size_adaptation.py:489, in DualAveragingStepSizeAdaptation.one_step(self, current_state, previous_kernel_results, seed)
#     487 # Step the inner kernel.
#     488 inner_kwargs = {} if seed is None else dict(seed=seed)
# --> 489 new_state, new_inner_results = self.inner_kernel.one_step(
#     490     current_state, inner_results, **inner_kwargs)
#     492 # Get the new step size.
#     493 log_accept_prob = self.log_accept_prob_getter_fn(new_inner_results)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/experimental/mcmc/preconditioned_nuts.py:343, in PreconditionedNoUTurnSampler.one_step(self, current_state, previous_kernel_results, seed)
#     338 momentum_distribution = previous_kernel_results.momentum_distribution
#     340 current_target_log_prob = previous_kernel_results.target_log_prob
#     341 [init_momentum,
#     342  init_energy,
# --> 343  log_slice_sample] = self._start_trajectory_batched(
#     344      current_state,
#     345      current_target_log_prob,
#     346      momentum_distribution=momentum_distribution,
#     347      seed=start_trajectory_seed)
#     349 def _copy(v):
#     350   return v * ps.ones(
#     351       ps.pad(
#     352           [2], paddings=[[0, ps.rank(v)]], constant_values=1),
#     353       dtype=v.dtype)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/experimental/mcmc/preconditioned_nuts.py:530, in PreconditionedNoUTurnSampler._start_trajectory_batched(self, state, target_log_prob, momentum_distribution, seed)
#     528 with tf.name_scope('start_trajectory_batched'):
#     529   momentum_seed, lss_seed = samplers.split_seed(seed, n=2)
# --> 530   momentum = momentum_distribution.sample(seed=momentum_seed)
#     531   init_energy = compute_hamiltonian(target_log_prob, momentum,
#     532                                     momentum_distribution)
#     534   if MULTINOMIAL_SAMPLE:
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1205, in Distribution.sample(self, sample_shape, seed, name, **kwargs)
#    1190 """Generate samples of the specified shape.
#    1191
#    1192 Note that a call to `sample()` without arguments will generate a single
#    (...)   1202   samples: a `Tensor` with prepended dimensions `sample_shape`.
#    1203 """
#    1204 with self._name_and_control_scope(name):
# -> 1205   return self._call_sample_n(sample_shape, seed, **kwargs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:956, in JointDistribution._call_sample_n(self, sample_shape, seed, value, **kwargs)
#     955 def _call_sample_n(self, sample_shape, seed, value=None, **kwargs):
# --> 956   return self._sample_n(
#     957       sample_shape,
#     958       seed=seed() if callable(seed) else seed,
#     959       value=self._resolve_value(value=value,
#     960                                 allow_partially_specified=True,
#     961                                 **kwargs))
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/distribution_util.py:1350, in AppendDocstring.__call__.<locals>._fn(*args, **kwargs)
#    1348 @functools.wraps(fn)
#    1349 def _fn(*args, **kwargs):
# -> 1350   return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:693, in JointDistribution._sample_n(self, sample_shape, seed, value)
#     683 @distribution_util.AppendDocstring(kwargs_dict={
#     684     'value': ('`Tensor`s structured like `type(model)` used to parameterize '
#     685               'other dependent ("downstream") distribution-making functions. '
#    (...)    691   # they're not already cached. This ensures we don't try to pass a stateless
#     692   # seed to a stateful sampler, or vice versa.
# --> 693   self._get_static_distribution_attributes(seed=seed)
#     695   might_have_batch_dims = (
#     696       distribution_util.shape_may_be_nontrivial(sample_shape)
#     697       or value is not None)
#     698   if might_have_batch_dims:
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:361, in JointDistribution._get_static_distribution_attributes(self, seed)
#     359 def _get_static_distribution_attributes(self, seed=None):
#     360   if not hasattr(self, '_cached_static_attributes'):
# --> 361     flat_list_of_static_attributes = callable_util.get_output_spec(
#     362         lambda: self._execute_model(  # pylint: disable=g-long-lambda
#     363             sample_and_trace_fn=trace_static_attributes,
#     364             seed=seed if seed is not None else samplers.zeros_seed()))
#     365     self._cached_static_attributes = StaticDistributionAttributes(
#     366         *zip(*flat_list_of_static_attributes))
#     368   return self._cached_static_attributes
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/callable_util.py:63, in get_output_spec(fn, *args, **kwargs)
#      60   return tf.TensorSpec.from_tensor(tf.convert_to_tensor(t))
#      61 arg_specs, kwarg_specs = tf.nest.map_structure(_as_tensor_spec,
#      62                                                (args, kwargs))
# ---> 63 return tf.function(fn, autograph=False).get_concrete_function(
#      64     *arg_specs, **kwarg_specs).structured_outputs
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:362, in JointDistribution._get_static_distribution_attributes.<locals>.<lambda>()
#     359 def _get_static_distribution_attributes(self, seed=None):
#     360   if not hasattr(self, '_cached_static_attributes'):
#     361     flat_list_of_static_attributes = callable_util.get_output_spec(
# --> 362         lambda: self._execute_model(  # pylint: disable=g-long-lambda
#     363             sample_and_trace_fn=trace_static_attributes,
#     364             seed=seed if seed is not None else samplers.zeros_seed()))
#     365     self._cached_static_attributes = StaticDistributionAttributes(
#     366         *zip(*flat_list_of_static_attributes))
#     368   return self._cached_static_attributes
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:1005, in JointDistribution._execute_model(self, sample_shape, seed, value, stop_index, sample_and_trace_fn)
#    1003   value_at_index = value[index]
#    1004 try:
# -> 1005   next_value, traced_values = sample_and_trace_fn(
#    1006       actual_distribution,
#    1007       sample_shape=sample_shape if isinstance(d, self.Root) else (),
#    1008       seed=(stateful_sample_seed if stateless_sample_seed is None
#    1009             else stateless_sample_seed),
#    1010       value=value_at_index)
#    1011 except TypeError as e:
#    1012   if ('Expected int for argument' not in str(e) and
#    1013       TENSOR_SEED_MSG_PREFIX not in str(e)) or (
#    1014           stateful_sample_seed is None):
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:156, in trace_static_attributes(***failed resolving arguments***)
#     154 del sample_shape
#     155 if value is None:
# --> 156   value = dist.sample(seed=seed)
#     157 return ValueWithTrace(
#     158     value=value,
#     159     traced=StaticDistributionAttributes(
#    (...)    164         name=get_explicit_name_for_component(dist),
#     165         reparameterization_type=dist.reparameterization_type))
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1205, in Distribution.sample(self, sample_shape, seed, name, **kwargs)
#    1190 """Generate samples of the specified shape.
#    1191
#    1192 Note that a call to `sample()` without arguments will generate a single
#    (...)   1202   samples: a `Tensor` with prepended dimensions `sample_shape`.
#    1203 """
#    1204 with self._name_and_control_scope(name):
# -> 1205   return self._call_sample_n(sample_shape, seed, **kwargs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1182, in Distribution._call_sample_n(self, sample_shape, seed, **kwargs)
#    1178 sample_shape = ps.convert_to_shape_tensor(
#    1179     ps.cast(sample_shape, tf.int32), name='sample_shape')
#    1180 sample_shape, n = self._expand_sample_shape_to_vector(
#    1181     sample_shape, 'sample_shape')
# -> 1182 samples = self._sample_n(
#    1183     n, seed=seed() if callable(seed) else seed, **kwargs)
#    1184 samples = tf.nest.map_structure(
#    1185     lambda x: tf.reshape(x, ps.concat([sample_shape, ps.shape(x)[1:]], 0)),
#    1186     samples)
#    1187 return self._set_sample_static_shape(samples, sample_shape, **kwargs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/batch_broadcast.py:299, in _BatchBroadcast._sample_n(self, n, seed)
#     296 def _sample_n(self, n, seed=None):
#     297   sample_shape = ps.reshape(n, [1])
#     298   x = self.distribution.sample(
# --> 299       self._augment_sample_shape(sample_shape), seed=seed)
#     300   return self._transpose_and_reshape_result(x, sample_shape=sample_shape)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/batch_broadcast.py:231, in _BatchBroadcast._augment_sample_shape(self, sample_shape)
#     224 def _augment_sample_shape(self, sample_shape):
#     225   # Suppose we have:
#     226   #   - sample shape of `[n]`,
#    (...)    229   # Then we must draw `sample_shape + [12]` samples, where
#     230   # `12 == n_batch // underlying_n_batch`.
# --> 231   batch_shape = self.batch_shape_tensor()
#     232   n_batch = ps.reduce_prod(batch_shape)
#     233   underlying_batch_shape = self.distribution.batch_shape_tensor()
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1004, in Distribution.batch_shape_tensor(self, name)
#     992 def batch_shape_tensor(self, name='batch_shape_tensor'):
# ...
#    1086       or all(len(path) == 1 and not isinstance(s, tf.TensorShape)
#    1087              for path, s in nest.flatten_with_tuple_paths(batch_shape))):
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/transformed_distribution.py:299, in _TransformedDistribution._batch_shape(self)
#     298 def _batch_shape(self):
# --> 299   batch_shape = self.distribution.batch_shape
#     300   if tf.nest.is_nested(batch_shape) and self._is_joint:
#     301     # Pass-through rudimentary support for JDs with structured batch shape.
#     302     # TODO(b/194742372): remove support for structured batch shape.
#     303     return tf.nest.pack_sequence_as(
#     304         self.dtype, tf.nest.flatten(batch_shape))
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1079, in Distribution.batch_shape(self)
#    1065 """Shape of a single sample from a single event index as a `TensorShape`.
#    1066
#    1067 May be partially defined or unknown.
#    (...)   1073   batch_shape: `TensorShape`, possibly unknown.
#    1074 """
#    1075 if not hasattr(self, '__cached_batch_shape'):
#    1076   # Cache the batch shape so that it's only inferred once. This is safe
#    1077   # because runtime changes to parameter shapes can only affect
#    1078   # `batch_shape_tensor`, never `batch_shape`.
# -> 1079   batch_shape = self._batch_shape()
#    1081   # See comment in `batch_shape_tensor()` on structured batch shapes. If
#    1082   # `_batch_shape()` is a `tf.TensorShape` instance or a flat list/tuple
#    1083   # that does not contain `tf.TensorShape`s, we infer that it is not
#    1084   # structured.
#    1085   if (isinstance(batch_shape, tf.TensorShape)
#    1086       or all(len(path) == 1 and not isinstance(s, tf.TensorShape)
#    1087              for path, s in nest.flatten_with_tuple_paths(batch_shape))):
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/transformed_distribution.py:299, in _TransformedDistribution._batch_shape(self)
#     298 def _batch_shape(self):
# --> 299   batch_shape = self.distribution.batch_shape
#     300   if tf.nest.is_nested(batch_shape) and self._is_joint:
#     301     # Pass-through rudimentary support for JDs with structured batch shape.
#     302     # TODO(b/194742372): remove support for structured batch shape.
#     303     return tf.nest.pack_sequence_as(
#     304         self.dtype, tf.nest.flatten(batch_shape))
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1079, in Distribution.batch_shape(self)
#    1065 """Shape of a single sample from a single event index as a `TensorShape`.
#    1066
#    1067 May be partially defined or unknown.
#    (...)   1073   batch_shape: `TensorShape`, possibly unknown.
#    1074 """
#    1075 if not hasattr(self, '__cached_batch_shape'):
#    1076   # Cache the batch shape so that it's only inferred once. This is safe
#    1077   # because runtime changes to parameter shapes can only affect
#    1078   # `batch_shape_tensor`, never `batch_shape`.
# -> 1079   batch_shape = self._batch_shape()
#    1081   # See comment in `batch_shape_tensor()` on structured batch shapes. If
#    1082   # `_batch_shape()` is a `tf.TensorShape` instance or a flat list/tuple
#    1083   # that does not contain `tf.TensorShape`s, we infer that it is not
#    1084   # structured.
#    1085   if (isinstance(batch_shape, tf.TensorShape)
#    1086       or all(len(path) == 1 and not isinstance(s, tf.TensorShape)
#    1087              for path, s in nest.flatten_with_tuple_paths(batch_shape))):
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1057, in Distribution._batch_shape(self)
#    1033 """Infers static batch shape from parameters.
#    1034
#    1035 The overall batch shape is inferred by broadcasting the batch shapes of
#    (...)   1054     be partially defined or unknown.
#    1055 """
#    1056 try:
# -> 1057   return batch_shape_lib.inferred_batch_shape(self)
#    1058 except NotImplementedError:
#    1059   # If a distribution doesn't implement `_parameter_properties` or its own
#    1060   # `_batch_shape` method, we can only return the most general shape.
#    1061   return tf.TensorShape(None)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/batch_shape_lib.py:68, in inferred_batch_shape(batch_object, bijector_x_event_ndims)
#      40 def inferred_batch_shape(batch_object, bijector_x_event_ndims=None):
#      41   """Infers an object's batch shape from its  parameters.
#      42
#      43   Each parameter contributes a batch shape of
#    (...)     66         be partially defined or unknown.
#      67   """
# ---> 68   batch_shapes = map_fn_over_parameters_with_event_ndims(
#      69       batch_object,
#      70       get_batch_shape_part,
#      71       require_static=True,
#      72       bijector_x_event_ndims=bijector_x_event_ndims)
#      73   return functools.reduce(tf.broadcast_static_shape,
#      74                           tf.nest.flatten(batch_shapes),
#      75                           tf.TensorShape([]))
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/batch_shape_lib.py:367, in map_fn_over_parameters_with_event_ndims(batch_object, fn, bijector_x_event_ndims, require_static, **parameter_kwargs)
#     361     elif (properties.is_tensor
#     362           and not tf.is_tensor(param)
#     363           and not tf.nest.is_nested(param_event_ndims)):
#     364       # As a last resort, try an explicit conversion.
#     365       param = tensor_util.convert_nonref_to_tensor(param, name=param_name)
# --> 367   results[param_name] = nest.map_structure_up_to(
#     368       param, fn, param, param_event_ndims)
#     369 return results
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/nest.py:1034, in map_structure_up_to(shallow_tree, func, *inputs, **kwargs)
#     960 @tf_export("__internal__.nest.map_structure_up_to", v1=[])
#     961 def map_structure_up_to(shallow_tree, func, *inputs, **kwargs):
#     962   """Applies a function or op to a number of partially flattened inputs.
#     963
#     964   The `inputs` are flattened up to `shallow_tree` before being mapped.
#    (...)   1032     `shallow_tree`.
#    1033   """
# -> 1034   return nest_util.map_structure_up_to(
#    1035       nest_util.Modality.CORE,
#    1036       shallow_tree,
#    1037       lambda _, *values: func(*values),  # Discards the path arg.
#    1038       *inputs,
#    1039       **kwargs,
#    1040   )
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1649, in map_structure_up_to(modality, shallow_tree, func, *inputs, **kwargs)
#    1575 """Applies a function or op to a number of partially flattened inputs.
#    1576
#    1577 The `inputs` are flattened up to `shallow_tree` before being mapped.
#    (...)   1646   `shallow_tree`.
#    1647 """
#    1648 if modality == Modality.CORE:
# -> 1649   return _tf_core_map_structure_with_tuple_paths_up_to(
#    1650       shallow_tree, func, *inputs, **kwargs
#    1651   )
#    1652 elif modality == Modality.DATA:
#    1653   return _tf_data_map_structure_up_to(shallow_tree, func, *inputs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1698, in _tf_core_map_structure_with_tuple_paths_up_to(shallow_tree, func, *inputs, **kwargs)
#    1683 flat_value_gen = (
#    1684     _tf_core_flatten_up_to(  # pylint: disable=g-complex-comprehension
#    1685         shallow_tree,
#    (...)   1690     for input_tree in inputs
#    1691 )
#    1692 flat_path_gen = (
#    1693     path
#    1694     for path, _ in _tf_core_yield_flat_up_to(
#    1695         shallow_tree, inputs[0], is_nested_fn
#    1696     )
#    1697 )
# -> 1698 results = [
#    1699     func(*args, **kwargs) for args in zip(flat_path_gen, *flat_value_gen)
#    1700 ]
#    1701 return _tf_core_pack_sequence_as(
#    1702     structure=shallow_tree,
#    1703     flat_sequence=results,
#    1704     expand_composites=expand_composites,
#    1705 )
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1699, in <listcomp>(.0)
#    1683 flat_value_gen = (
#    1684     _tf_core_flatten_up_to(  # pylint: disable=g-complex-comprehension
#    1685         shallow_tree,
#    (...)   1690     for input_tree in inputs
#    1691 )
#    1692 flat_path_gen = (
#    1693     path
#    1694     for path, _ in _tf_core_yield_flat_up_to(
#    1695         shallow_tree, inputs[0], is_nested_fn
#    1696     )
#    1697 )
#    1698 results = [
# -> 1699     func(*args, **kwargs) for args in zip(flat_path_gen, *flat_value_gen)
#    1700 ]
#    1701 return _tf_core_pack_sequence_as(
#    1702     structure=shallow_tree,
#    1703     flat_sequence=results,
#    1704     expand_composites=expand_composites,
#    1705 )
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/nest.py:1037, in map_structure_up_to.<locals>.<lambda>(_, *values)
#     960 @tf_export("__internal__.nest.map_structure_up_to", v1=[])
#     961 def map_structure_up_to(shallow_tree, func, *inputs, **kwargs):
#     962   """Applies a function or op to a number of partially flattened inputs.
#     963
#     964   The `inputs` are flattened up to `shallow_tree` before being mapped.
#    (...)   1032     `shallow_tree`.
#    1033   """
#    1034   return nest_util.map_structure_up_to(
#    1035       nest_util.Modality.CORE,
#    1036       shallow_tree,
# -> 1037       lambda _, *values: func(*values),  # Discards the path arg.
#    1038       *inputs,
#    1039       **kwargs,
#    1040   )
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/batch_shape_lib.py:156, in get_batch_shape_part(x, event_ndims)
#     151   except NotImplementedError:
#     152     # Backwards compatibility with bijector-like instances that don't
#     153     # inherit from tfb.Bijector (e.g., Distrax bijectors) and/or don't
#     154     # implement `_parameter_properties`.
#     155     return tf.TensorShape([])
# --> 156 if hasattr(x, 'batch_shape'):  # `x` is a distribution or linear operator.
#     157   base_shape = x.batch_shape
#     158   # Hack to attempt to collapse non-autobatched JDs to a coherent batch shape.
#     159   # Distrax distributions have tuple-valued batch shapes, which are
#     160   # always spuriously 'nested', so to avoid confusion we check that the
#     161   # distribution is actually a joint distribution (Distrax
#     162   # distributions are always single-part).
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1079, in Distribution.batch_shape(self)
#    1065 """Shape of a single sample from a single event index as a `TensorShape`.
#    1066
#    1067 May be partially defined or unknown.
#    (...)   1073   batch_shape: `TensorShape`, possibly unknown.
#    1074 """
#    1075 if not hasattr(self, '__cached_batch_shape'):
#    1076   # Cache the batch shape so that it's only inferred once. This is safe
#    1077   # because runtime changes to parameter shapes can only affect
#    1078   # `batch_shape_tensor`, never `batch_shape`.
# -> 1079   batch_shape = self._batch_shape()
#    1081   # See comment in `batch_shape_tensor()` on structured batch shapes. If
#    1082   # `_batch_shape()` is a `tf.TensorShape` instance or a flat list/tuple
#    1083   # that does not contain `tf.TensorShape`s, we infer that it is not
#    1084   # structured.
#    1085   if (isinstance(batch_shape, tf.TensorShape)
#    1086       or all(len(path) == 1 and not isinstance(s, tf.TensorShape)
#    1087              for path, s in nest.flatten_with_tuple_paths(batch_shape))):
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1057, in Distribution._batch_shape(self)
#    1033 """Infers static batch shape from parameters.
#    1034
#    1035 The overall batch shape is inferred by broadcasting the batch shapes of
#    (...)   1054     be partially defined or unknown.
#    1055 """
#    1056 try:
# -> 1057   return batch_shape_lib.inferred_batch_shape(self)
#    1058 except NotImplementedError:
#    1059   # If a distribution doesn't implement `_parameter_properties` or its own
#    1060   # `_batch_shape` method, we can only return the most general shape.
#    1061   return tf.TensorShape(None)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/batch_shape_lib.py:68, in inferred_batch_shape(batch_object, bijector_x_event_ndims)
#      40 def inferred_batch_shape(batch_object, bijector_x_event_ndims=None):
#      41   """Infers an object's batch shape from its  parameters.
#      42
#      43   Each parameter contributes a batch shape of
#    (...)     66         be partially defined or unknown.
#      67   """
# ---> 68   batch_shapes = map_fn_over_parameters_with_event_ndims(
#      69       batch_object,
#      70       get_batch_shape_part,
#      71       require_static=True,
#      72       bijector_x_event_ndims=bijector_x_event_ndims)
#      73   return functools.reduce(tf.broadcast_static_shape,
#      74                           tf.nest.flatten(batch_shapes),
#      75                           tf.TensorShape([]))
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow_probability/python/internal/batch_shape_lib.py:367, in map_fn_over_parameters_with_event_ndims(batch_object, fn, bijector_x_event_ndims, require_static, **parameter_kwargs)
#     361     elif (properties.is_tensor
#     362           and not tf.is_tensor(param)
#     363           and not tf.nest.is_nested(param_event_ndims)):
#     364       # As a last resort, try an explicit conversion.
#     365       param = tensor_util.convert_nonref_to_tensor(param, name=param_name)
# --> 367   results[param_name] = nest.map_structure_up_to(
#     368       param, fn, param, param_event_ndims)
#     369 return results
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/nest.py:1034, in map_structure_up_to(shallow_tree, func, *inputs, **kwargs)
#     960 @tf_export("__internal__.nest.map_structure_up_to", v1=[])
#     961 def map_structure_up_to(shallow_tree, func, *inputs, **kwargs):
#     962   """Applies a function or op to a number of partially flattened inputs.
#     963
#     964   The `inputs` are flattened up to `shallow_tree` before being mapped.
#    (...)   1032     `shallow_tree`.
#    1033   """
# -> 1034   return nest_util.map_structure_up_to(
#    1035       nest_util.Modality.CORE,
#    1036       shallow_tree,
#    1037       lambda _, *values: func(*values),  # Discards the path arg.
#    1038       *inputs,
#    1039       **kwargs,
#    1040   )
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1649, in map_structure_up_to(modality, shallow_tree, func, *inputs, **kwargs)
#    1575 """Applies a function or op to a number of partially flattened inputs.
#    1576
#    1577 The `inputs` are flattened up to `shallow_tree` before being mapped.
#    (...)   1646   `shallow_tree`.
#    1647 """
#    1648 if modality == Modality.CORE:
# -> 1649   return _tf_core_map_structure_with_tuple_paths_up_to(
#    1650       shallow_tree, func, *inputs, **kwargs
#    1651   )
#    1652 elif modality == Modality.DATA:
#    1653   return _tf_data_map_structure_up_to(shallow_tree, func, *inputs)
#
# File ~/.pyenv/versions/meridian/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1667, in _tf_core_map_structure_with_tuple_paths_up_to(shallow_tree, func, *inputs, **kwargs)
#    1664 if not inputs:
#    1665   raise ValueError("Cannot map over no sequences")
# -> 1667 check_types = kwargs.pop("check_types", True)
#    1668 expand_composites = kwargs.pop("expand_composites", False)
#    1669 is_nested_fn = (
#    1670     _is_nested_or_composite if expand_composites else _tf_core_is_nested
#    1671 )
#
# KeyboardInterrupt:

# %% [markdown]
# For more information about configuring the parameters and using a customized model specification, such as setting different ROI priors for each media channel, see [Configure the model](https://developers.google.com/meridian/docs/user-guide/configure-model).

# %% [markdown]
# <a name="model-diagnostics"></a>
# ## Step 3: Run model diagnostics

# %% [markdown]
# After the model is built, you must assess convergence, debug the model if needed, and then assess the model fit.
#
# 1\. Assess convergence. Run the following code to generate r-hat statistics. R-hat close to 1.0 indicate convergence. R-hat < 1.2 indicates approximate convergence and is a reasonable threshold for many problems.

# %%
model_diagnostics = visualizer.ModelDiagnostics(mmm)
model_diagnostics.plot_rhat_boxplot()

# %% [markdown]
# 2\. Assess the model's fit by comparing the expected sales against the actual sales.

# %%
model_fit = visualizer.ModelFit(mmm)
model_fit.plot_model_fit()

# %% [markdown]
# For more information and additional model diagnostics checks, see [Modeling diagnostics](https://developers.google.com/meridian/docs/user-guide/model-diagnostics).

# %% [markdown]
# <a name="generate-summary"></a>
# ## Step 4: Generate model results & two-page output

# %% [markdown]
# To export the two-page HTML summary output, initialize the `Summarizer` class with the model object. Then pass in the filename, filepath, start date, and end date to `output_model_results_summary` to run the summary for that time duration and save it to the specified file.

# %%
mmm_summarizer = summarizer.Summarizer(mmm)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
filepath = '/content/drive/MyDrive'
start_date = '2021-01-25'
end_date = '2024-01-15'
mmm_summarizer.output_model_results_summary('summary_output.html', filepath, start_date, end_date)

# %% [markdown]
# Here is a preview of the two-page output based on the simulated data:

# %%
IPython.display.HTML(filename='/content/drive/MyDrive/summary_output.html')

# %% [markdown]
# For a customized two-page report, model results summary table, and individual visualizations, see [Model results report](https://developers.google.com/meridian/docs/user-guide/generate-model-results-report) and [plot media visualizations](https://developers.google.com/meridian/docs/user-guide/plot-media-visualizations).

# %% [markdown]
# <a name="generate-optimize"></a>
# ## Step 5: Run budget optimization & generate an optimization report

# %% [markdown]
# You can choose what scenario to run for the budget allocation. In default scenario, you find the optimal allocation across channels for a given budget to maximize the return on investment (ROI).
#
# 1\. Instantiate the `BudgetOptimizer` class and run the `optimize()` method without any customization, to run the default library's Fixed Budget Scenario to maximize ROI.

# %%
# %%time
budget_optimizer = optimizer.BudgetOptimizer(mmm)
optimization_results = budget_optimizer.optimize()

# %% [markdown]
# 2\. Export the 2-page HTML optimization report, which contains optimized spend allocations and ROI.

# %%
filepath = '/content/drive/MyDrive'
optimization_results.output_optimization_summary('optimization_output.html', filepath)

# %%
IPython.display.HTML(filename='/content/drive/MyDrive/optimization_output.html')

# %% [markdown]
# For information about customized optimization scenarios, such as flexible budget scenarios, see [Budget optimization scenarios](https://developers.google.com/meridian/docs/user-guide/budget-optimization-scenarios). For more information about optimization results summary and individual visualizations, see [optimization results output](https://developers.google.com/meridian/docs/user-guide/generate-optimization-results-output) and [optimization visualizations](https://developers.google.com/meridian/docs/user-guide/plot-optimization-visualizations).

# %% [markdown]
# <a name="save-model"></a>
# ## Step 6: Save the model object

# %% [markdown]
# We recommend that you save the model object for future use. This helps you to  avoid repetitive model runs and saves time and computational resources. After the model object is saved, you can load it at a later stage to continue the analysis or visualizations without having to re-run the model.

# %% [markdown]
# Run the following codes to save the model object:

# %%
file_path='/content/drive/MyDrive/saved_mmm.pkl'
model.save_mmm(mmm, file_path)

# %% [markdown]
# Run the following codes to load the saved model:

# %%
mmm = model.load_mmm(file_path)
