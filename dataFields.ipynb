# %%
import pandas as pd

# %%
tables = pd.read_csv('data/bigQueryDataReview/bigQuery_tables.csv')
columns = pd.read_csv('data/bigQueryDataReview/bigQuery_fields.csv')

# %%
tables
# Out:
#              table_catalog         table_schema  \
# 0     prod-data-enablement     datalake_marketo
# 1     prod-data-enablement     datalake_marketo
# 2     prod-data-enablement     datalake_marketo
# 3     prod-data-enablement     datalake_marketo
# 4     prod-data-enablement     datalake_marketo
# ...                    ...                  ...
# 5460  prod-data-enablement  bigquery_audit_logs
# 5461  prod-data-enablement  bigquery_audit_logs
# 5462  prod-data-enablement  bigquery_audit_logs
# 5463  prod-data-enablement  bigquery_audit_logs
# 5464  prod-data-enablement  bigquery_audit_logs
#
#                                            table_name  table_type  \
# 0                                                form  BASE TABLE
# 1                                         merged_lead  BASE TABLE
# 2                                             program  BASE TABLE
# 3                                  program_membership  BASE TABLE
# ...

# %%
columns
# Out:
#               table_catalog         table_schema                   table_name  \
# 0      prod-data-enablement         finance_prod      base_contract_analytics
# 1      prod-data-enablement         finance_prod      base_contract_analytics
# 2      prod-data-enablement         finance_prod      base_contract_analytics
# 3      prod-data-enablement         finance_prod      base_contract_analytics
# 4      prod-data-enablement         finance_prod      base_contract_analytics
# ...                     ...                  ...                          ...
# 49637  prod-data-enablement  datalake_platformdb       raw_iracct_credit_memo
# 49638  prod-data-enablement  datalake_platformdb       raw_iracct_credit_memo
# 49639  prod-data-enablement  datalake_platformdb       raw_iracct_credit_memo
# 49640  prod-data-enablement  datalake_platformdb  raw_iram_adv_funding_status
# 49641  prod-data-enablement  datalake_platformdb  raw_iram_adv_funding_status
#
# ...

# %%
df = columns[(columns['column_name'].str.contains('mql')) & (columns['table_schema'].str.contains('sandbox')==False)]

# %%
df = columns[(columns['column_name'].str.contains('directmail')) & (columns['table_schema'].str.contains('sandbox')==False)]
df
# Out:
#               table_catalog           table_schema     table_name  \
# 46789  prod-data-enablement  datalake_irdwm_backup  publisher_dim
# 47337  prod-data-enablement  datalake_irdwm_backup      media_dim
#
#                         column_name  ordinal_position is_nullable data_type  \
# 46789  prom_mthd_offline_directmail                58         YES     INT64
# 47337  prom_mthd_offline_directmail                81         YES     INT64
#
#       is_generated  generation_expression  is_stored is_hidden  is_updatable  \
# 46789        NEVER                    NaN        NaN        NO           NaN
# 47337        NEVER                    NaN        NaN        NO           NaN
#
#       is_system_defined is_partitioning_column  clustering_ordinal_position  \
# 46789                NO                     NO                          NaN
# 47337                NO                     NO                          NaN
#
#        collation_name  column_default  rounding_mode policy_tags
# ...

# %%
path = 'data/bigQueryDataReview/'

# %% [markdown]
# # cost_columns

# %%
df = columns[(columns['column_name'].str.contains('cost')) & (columns['table_schema'].str.contains('sandbox')==False)]
outputfile =path+'queries_cost_fields.csv'

# %%
df[['table_name', 'table_schema','table_catalog', 'column_name', 'data_type']].groupby(['table_name', 'table_schema','table_catalog', 'column_name']).count().to_csv(outputfile)

# %%
df
# Out:
#               table_catalog            table_schema  \
# 2579   prod-data-enablement          datalake_pendo
# 3776   prod-data-enablement  datalake_irdwm_iceberg
# 3777   prod-data-enablement  datalake_irdwm_iceberg
# 3778   prod-data-enablement  datalake_irdwm_iceberg
# 3779   prod-data-enablement  datalake_irdwm_iceberg
# ...                     ...                     ...
# 47584  prod-data-enablement     datalake_platformdb
# 48847  prod-data-enablement     datalake_platformdb
# 48848  prod-data-enablement     datalake_platformdb
# 49412  prod-data-enablement     datalake_platformdb
# 49437  prod-data-enablement     datalake_platformdb
#
#                                   table_name  \
# 2579                         account_history
# 3776                         agg_daily_brand
# 3777                         agg_daily_brand
# 3778                         agg_daily_brand
# 3779                         agg_daily_brand
# ...                                      ...
# ...

# %%
cost_columns= df.copy()

# %% [markdown]
# # Alyce Columns

# %%
df = columns[(columns['column_name'].str.contains('alyce')) & (columns['table_schema'].str.contains('sandbox')==False)]
outputfile = path + 'queries_alyce_fields.csv'

# %%
df[['table_name', 'table_schema','table_catalog', 'column_name', 'data_type']].groupby(['table_name', 'table_schema','table_catalog', 'column_name']).count()
# Out:
#                                                                                                                                      data_type
# table_name            table_schema                          table_catalog        column_name
# account               datalake_salesforce_fivetran          prod-data-enablement alycecom_initial_gift_invitation_create_date_c              1
#                                                                                  alycecom_initial_gift_invitation_sent_date_c                1
#                                                                                  alycecom_most_recent_gift_invitation_create_date_c          1
#                                                                                  alycecom_most_recent_gift_invitation_sent_date_c            1
#                                                                                  alycecom_total_gifts_invitations_sent_to_account_c          1
# ...

# %%
df[['table_name', 'table_schema','table_catalog', 'column_name', 'data_type']].groupby(['table_name', 'table_schema','table_catalog', 'column_name']).count().to_csv(outputfile)

# %%
alyce_columns = df.copy()
